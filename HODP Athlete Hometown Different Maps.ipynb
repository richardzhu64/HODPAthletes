# %%
import numpy as np
import pandas as pd
import geopy as gp
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

geolocator = Nominatim(user_agent="hello")

# %%
df = pd.read_csv('HODP Athlete Project - All Athletes.csv', index_col = 0)
df = df[pd.notnull(df['Hometown'])]
df = df.reset_index()
df.drop(columns = ['Unnamed: 8'])
df.head()
# Out:
#       Sport Gender            Name Yr.               Hometown  \
# 0  Baseball      M  Seamus Buckley  Fy      Dorchester, Mass.
# 1  Baseball      M     Ian Buckner  Fy       Oak Park, Calif.
# 2  Baseball      M   Will Jacobsen  Fy  San Francisco, Calif.
# 3  Baseball      M      Ben Rounds  Fy          Milton, Mass.
# 4  Baseball      M    Pryor Thomas  Fy          Keller, Texas
#
#                 High School  \
# 0        Beaver Country Day
# 1    Grace Brethren Academy
# 2        The Branson School
# 3             Roxbury Latin
# 4  Liberty Christian School
#
#   Median Household Income from datausa.io, or ZIP code from https://www.incomebyzipcode.com  \
# 0                                             71,723
# 1                                            129,721
# 2                                            110,816
# 3                                            126,000
# 4                                             126013
#
#   Private School Unnamed: 8
# 0              1    103,092
# 1              1        NaN
# 2              1        NaN
# 3              1        NaN
# 4              1        NaN

# %%
print(df.iloc[0].Hometown)
# Out:
# Dorchester, Mass.

# %%
def do_geocode(address):
    try:
        return geolocator.geocode(address)
    except GeocoderTimedOut:
        return do_geocode(address)

# %%
print(do_geocode("New York, New York"))
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-171ad68273cd> in <module>
# ----> 1 print(do_geocode("New York, New York"))
#
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-27-dbf3dbff9dc3> in do_geocode(address)
#       1 def do_geocode(address):
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#       5         return do_geocode(address)
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     385
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#     389
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     353
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#     357             message = (
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1382             "Connect to a host on a given (SSL) port."
#    1383
# -> 1384             super().connect()
#    1385
#    1386             if self._tunnel_host:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     926         """Connect to the host and port specified in __init__."""
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     930
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:

# %%
# Cleaner function
def cleaner(old, new):
    lst = [] 
    for i, row in df.iterrows():
        if old in row["Hometown"]:
            lst.append(i)

    print(lst)
    for i in lst:
        df.iloc[i]["Hometown"] = df.iloc[i]["Hometown"].replace(old, new)
        
cleaner("Ill.", "Illinois")
cleaner("Neb.", "Nebraska")
cleaner("Wisc.", "Wisconsin")
cleaner("Fla", "Florida")
cleaner("Coquitlan", "Coquitlam")
cleaner("Pozos de Santa", "Pozos")
cleaner("Cutchouge", "Cutchogue")
cleaner("Edgarton", "Edgartown")
# Out:
# [43, 70, 74, 77, 167, 204, 216, 220, 279, 360, 444, 452, 455, 456, 458, 497, 515, 541, 548, 620, 632, 639, 673, 675, 682, 699, 702, 759, 769, 779, 822, 863, 909, 992, 993, 1003, 1030]
# [73]
# [121, 568, 714]
# [8, 57, 107, 157, 163, 206, 244, 245, 254, 256, 284, 317, 334, 339, 340, 424, 436, 466, 471, 476, 494, 519, 553, 580, 595, 600, 631, 648, 667, 670, 830, 847, 927, 946, 947, 948, 1049]
# [474, 598]
# [662]
# [732]
# [967]

# %%
print(df.iloc[732].Hometown)
# Out:
# Cutchogue, N.Y.

# %%
df = df.iloc[0:len(df.Hometown)]
df
# Out:
#               Sport Gender                    Name         Yr.  \
# 0          Baseball      M          Seamus Buckley          Fy
# 1          Baseball      M             Ian Buckner          Fy
# 2          Baseball      M           Will Jacobsen          Fy
# 3          Baseball      M              Ben Rounds          Fy
# 4          Baseball      M            Pryor Thomas          Fy
# 5          Baseball      M        Spencer Williams          Fy
# 6          Baseball      M          Tim Williamson          Fy
# 7          Baseball      M              Adam Stone         Fy.
# 8          Baseball      M           Buddy Hayward         Jr.
# 9          Baseball      M             Jack Mahala         Jr.
# 10         Baseball      M           Chris McGrory         Jr.
# 11         Baseball      M            Buddy Mrowka         Jr.
# 12         Baseball      M             Tommy Seidl         Jr.
# 13         Baseball      M          Enzo Stefanoni         Jr.
# 14         Baseball      M             Matt Thomas         Jr.
# 15         Baseball      M              Jaren Zinn         Jr.
# 16         Baseball      M          Hunter Baldwin         So.
# 17         Baseball      M            Chase Bookin         So.
# 18         Baseball      M             Logan Bravo         So.
# 19         Baseball      M           Zachary Brown         So.
# 20         Baseball      M         Matthew Jenkins         So.
# 21         Baseball      M       James Kirkpatrick         So.
# 22         Baseball      M        Joseph O'Connell         So.
# 23         Baseball      M        Harrison Stovern         So.
# 24         Baseball      M              JT Bernard         Sr.
# 25         Baseball      M           Quinn Hoffman         Sr.
# 26         Baseball      M             Chad Minato         Sr.
# 27         Baseball      M             Kieran Shaw         Sr.
# 28         Baseball      M             Grant Stone         Sr.
# 29         Baseball      M          Jake Suddleson         Sr.
# ...             ...    ...                     ...         ...
# 1022  Cross Country      F  Valentina Doerre Torre   Sophomore
# 1023  Cross Country      F          Eloise Freitag  First-Year
# 1024  Cross Country      F          Abbe Goldstein      Junior
# 1025  Cross Country      F         Tatiana Jimenez      Junior
# 1026  Cross Country      F               Anna Juul      Junior
# 1027  Cross Country      F        Shaked Leibovitz  First-Year
# 1028  Cross Country      F           Tessa Medrano      Junior
# 1029  Cross Country      F           Gillian Meeks      Senior
# 1030  Cross Country      F         Judy Pendergast      Senior
# 1031  Cross Country      F              Maya Rayle   Sophomore
# 1032  Cross Country      F              Eliza Rego      Senior
# 1033  Cross Country      F                Iz Sagar  First-Year
# 1034  Cross Country      F            Brooke Starn      Senior
# 1035  Cross Country      F            Lisa Tertsch      Senior
# 1036  Cross Country      F           Jordan Weston   Sophomore
# 1037         Tennis      F           Annika Bassey   Sophomore
# 1038         Tennis      F            Rachel Eason   Sophomore
# 1039         Tennis      F           Jenna Friedel      Senior
# 1040         Tennis      F        Natasha Gonzalez      Senior
# 1041         Tennis      F              Neha Gupta      Junior
# 1042         Tennis      F               Sophia Ho  First-Year
# 1043         Tennis      F           Kayla Leschly  First-Year
# 1044         Tennis      F                 Anna Li      Junior
# 1045         Tennis      F              Rachel Lim   Sophomore
# 1046         Tennis      F                Irene Lu      Senior
# 1047         Tennis      F      Mihaela Marculescu  First-Year
# 1048         Tennis      F         Lexi Milunovich      Senior
# 1049         Tennis      F             Demi Snyder  First-Year
# 1050         Tennis      F        Chelsea Williams   Sophomore
# 1033                                          Loyalsock
# 1034                                        Monte Vista
# 1035                                      ASC Darmstadt
# 1036                                   Glebe Collegiate
# 1037                            Corona Del Mar (Calif.)
# 1038                                        James Logan
# 1039  The College Preparatory School/K12 Internation...
# 1040                                  St. John's School
# 1041                                      Cosumnes Oaks
# 1042                        Port Moody Secondary School
# 1043                                             Weston
# 1044                                    North Allegheny
# 1045                                         Briarcliff
# 1046                                           Atholton
# 1047                                        Tudor Vianu
# 1048                                  Greenwich Academy
# 1049                                  Pine Crest School
# 1050                                 Brooklyn Technical
# 1051  Thomas Jefferson High School for Science and T...
#
#      Median Household Income from datausa.io, or ZIP code from https://www.incomebyzipcode.com  \
# 0                                                71,723
# 1                                               129,721
# 2                                               110,816
# 3                                               126,000
# 4                                                126013
# 5                                                67,906
# 6                                                103092
# 7                                                84,893
# 8                                                69,531
# 9                                               112,083
# 10                                              131,852
# 11                                              150,625
# 12                                              176,852
# 13                                              208,848
# 14                                               65,006
# 15                                               82,372
# 16                                               50,896
# 17                                              148,899
# 18                                               83,910
# 19                                               73,865
# 20                                                  NaN
# 21                                               50,896
# 22                                               57,737
# 23                                              174,194
# 24                                               51,039
# 25                                              122,563
# 26                                               88,079
# 27                                              132,671
# 28                                               84,893
# 29                                              180,962
# ...                                                 ...
# 1022                                                NaN
# 1023                                             60,879
# 1024                                                NaN
# 1025                                                NaN
# 1026                                                NaN
# 1027                                                NaN
# 1028                                                NaN
# 1029                                            147,537
# 1030                                            114,014
# 1031                                             66,187
# 1032                                                NaN
# 1033                                                NaN
# 1034                                            152,798
# 1035                                                NaN
# 1036                                              65782
# 1037                                             65,224
# 1038                                             95,625
# 1039                                                NaN
# 1040                                             50,896
# 1041                                                NaN
# 1042                                                NaN
# 1043                                            196,651
# 1044                                                NaN
# 1045                                            157,963
# 1046                                                NaN
# 1047                                                NaN
# 1048                                            147,128
# 1049                                             52,315
# 1050                                             85,846
# 1051                                                NaN
#
#      Private School Unnamed: 8
# 0                 1    103,092
# 1                 1        NaN
# 2                 1        NaN
# 3                 1        NaN
# 4                 1        NaN
# 5                 1        NaN
# 6                 1        NaN
# 7                 1        NaN
# 8                 1        NaN
# 9                 1        NaN
# 10                0        NaN
# 11                1        NaN
# 12                1        NaN
# 13                1        NaN
# 14                1        NaN
# 15                1        NaN
# 16                0        NaN
# 17                1        NaN
# 18                1        NaN
# 19                0        NaN
# 20                1        NaN
# 21                0        NaN
# 22                1        NaN
# 23                0        NaN
# 24                1        NaN
# 25                1        NaN
# 26                0        NaN
# 27                1        NaN
# 28                1        NaN
# 29                1        NaN
# ...             ...        ...
# 1022            NaN        NaN
# 1023            NaN        NaN
# 1024            NaN        NaN
# 1025            NaN        NaN
# 1026            NaN        NaN
# 1027            NaN        NaN
# 1028            NaN        NaN
# 1029            NaN        NaN
# 1030            NaN        NaN
# 1031            NaN        NaN
# 1032            NaN        NaN
# 1033            NaN        NaN
# 1034            NaN        NaN
# 1035            NaN        NaN
# 1036            NaN        NaN
# 1037            NaN        NaN
# 1038            NaN        NaN
# 1039            NaN        NaN
# 1040            NaN        NaN
# 1041            NaN        NaN
# 1042            NaN        NaN
# 1043            NaN        NaN
# 1044            NaN        NaN
# 1045            NaN        NaN
# 1046            NaN        NaN
# 1047            NaN        NaN
# 1048            NaN        NaN
# 1049            NaN        NaN
# 1050            NaN        NaN
# 1051            NaN        NaN
#
# [1052 rows x 9 columns]

# %%
def do_geocode(address):
    try:
        return geolocator.geocode(address)
    except GeocoderTimedOut:
        return do_geocode(address)

# %%
small_df = df[:100]
small_df
# Out:
#                Sport Gender                Name         Yr.  \
# 0           Baseball      M      Seamus Buckley          Fy
# 1           Baseball      M         Ian Buckner          Fy
# 2           Baseball      M       Will Jacobsen          Fy
# 3           Baseball      M          Ben Rounds          Fy
# 4           Baseball      M        Pryor Thomas          Fy
# 5           Baseball      M    Spencer Williams          Fy
# 6           Baseball      M      Tim Williamson          Fy
# 7           Baseball      M          Adam Stone         Fy.
# 8           Baseball      M       Buddy Hayward         Jr.
# 9           Baseball      M         Jack Mahala         Jr.
# 10          Baseball      M       Chris McGrory         Jr.
# 11          Baseball      M        Buddy Mrowka         Jr.
# 12          Baseball      M         Tommy Seidl         Jr.
# 13          Baseball      M      Enzo Stefanoni         Jr.
# 14          Baseball      M         Matt Thomas         Jr.
# 15          Baseball      M          Jaren Zinn         Jr.
# 16          Baseball      M      Hunter Baldwin         So.
# 17          Baseball      M        Chase Bookin         So.
# 18          Baseball      M         Logan Bravo         So.
# 19          Baseball      M       Zachary Brown         So.
# 20          Baseball      M     Matthew Jenkins         So.
# 21          Baseball      M   James Kirkpatrick         So.
# 22          Baseball      M    Joseph O'Connell         So.
# 23          Baseball      M    Harrison Stovern         So.
# 24          Baseball      M          JT Bernard         Sr.
# 25          Baseball      M       Quinn Hoffman         Sr.
# 26          Baseball      M         Chad Minato         Sr.
# 27          Baseball      M         Kieran Shaw         Sr.
# 28          Baseball      M         Grant Stone         Sr.
# 29          Baseball      M      Jake Suddleson         Sr.
# ..               ...    ...                 ...         ...
# 70     Swim and Dive      M         Nick Nocita  First-Year
# 71     Swim and Dive      M           Kevin Ong  First-Year
# 72     Swim and Dive      M         Moritz Pail  First-Year
# 73     Swim and Dive      M          Alex Petty  First-Year
# 74     Swim and Dive      M       Daniel Puczko   Sophomore
# 75     Swim and Dive      M        Corban Rawls      Junior
# 76     Swim and Dive      M      Mahlon Reihman      Junior
# 77     Swim and Dive      M       Jared Simpson   Sophomore
# 78     Swim and Dive      M         Zach Snyder      Senior
# 79     Swim and Dive      M     Charles Vaughan      Junior
# 80     Swim and Dive      M      Eric Whisenant      Junior
# 81     Swim and Dive      M      Michael Zarian      Junior
# 82            Squash      M  Saadeldin Abouaish      Senior
# 83            Squash      M    Timothy Brownell      Senior
# 84            Squash      M       Adam Corcoran      Junior
# 85            Squash      M       Victor Crouin   Sophomore
# 86            Squash      M       George Crowne   Sophomore
# 87            Squash      M       Julien Gosset      Junior
# 88            Squash      M         Sean Hughes      Senior
# 89            Squash      M         Ayush Menon  First-Year
# 90            Squash      M     John Finley Ong      Junior
# 91            Squash      M        Liam Rotzoll  First-Year
# 92            Squash      M       Samuel Scherl      Junior
# 97             Greenwich, Conn.                       Greenwich
# 98    Salisbury, United Kingdom                    Eton College
# 99              Westport, Conn.                         Staples
#
#    Median Household Income from datausa.io, or ZIP code from https://www.incomebyzipcode.com  \
# 0                                              71,723
# 1                                             129,721
# 2                                             110,816
# 3                                             126,000
# 4                                              126013
# 5                                              67,906
# 6                                              103092
# 7                                              84,893
# 8                                              69,531
# 9                                             112,083
# 10                                            131,852
# 11                                            150,625
# 12                                            176,852
# 13                                            208,848
# 14                                             65,006
# 15                                             82,372
# 16                                             50,896
# 17                                            148,899
# 18                                             83,910
# 19                                             73,865
# 20                                                NaN
# 21                                             50,896
# 22                                             57,737
# 23                                            174,194
# 24                                             51,039
# 25                                            122,563
# 26                                             88,079
# 27                                            132,671
# 28                                             84,893
# 29                                            180,962
# ..                                                ...
# 70                                             87,790
# 71                                                NaN
# 72                                                NaN
# 73                                             60,057
# 74                                             55,295
# 75                                            153,449
# 76                                             38,522
# 77                                            114,014
# 78                                             55,859
# 79                                            109,201
# 80                                             43,552
# 81                                             75,640
# 82                                                NaN
# 83                                            118,370
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                            116,667
# 89                                             95,622
# 90                                             81,546
# 91                                            154,559
# 92                                            121,637
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                             94,309
# 98                                                NaN
# 99                                            181,360
#
#    Private School Unnamed: 8
# 0               1    103,092
# 1               1        NaN
# 2               1        NaN
# 3               1        NaN
# 4               1        NaN
# 5               1        NaN
# 6               1        NaN
# 7               1        NaN
# 8               1        NaN
# 9               1        NaN
# 10              0        NaN
# 11              1        NaN
# 12              1        NaN
# 13              1        NaN
# 14              1        NaN
# 15              1        NaN
# 16              0        NaN
# 17              1        NaN
# 18              1        NaN
# 19              0        NaN
# 20              1        NaN
# 21              0        NaN
# 22              1        NaN
# 23              0        NaN
# 24              1        NaN
# 25              1        NaN
# 26              0        NaN
# 27              1        NaN
# 28              1        NaN
# 29              1        NaN
# ..            ...        ...
# 70            NaN        NaN
# 71            NaN        NaN
# 72            NaN        NaN
# 73            NaN        NaN
# 74            NaN        NaN
# 75            NaN        NaN
# 76            NaN        NaN
# 77            NaN        NaN
# 78            NaN        NaN
# 79            NaN        NaN
# 80            NaN        NaN
# 81            NaN        NaN
# 82            NaN        NaN
# 83            NaN        NaN
# 84            NaN        NaN
# 85            NaN        NaN
# 86            NaN        NaN
# 87            NaN        NaN
# 88            NaN        NaN
# 89            NaN        NaN
# 90              1        NaN
# 91            NaN        NaN
# 92            NaN        NaN
# 93            NaN        NaN
# 94            NaN        NaN
# 95            NaN        NaN
# 96            NaN        NaN
# 97            NaN        NaN
# 98            NaN        NaN
# 99            NaN        NaN
#
# [100 rows x 9 columns]

# %%
# df['CHometown'] = df.apply(lambda row: do_geocode(row["Hometown"]).address, axis=1)

for index, row in small_df.iterrows():
    print(index, row["Hometown"])
    # location = do_geocode(row["Hometown"])
    # print(index)
    # row['CHometown'] = location.address
# Out:
# 0 Dorchester, Mass.
# 1 Oak Park, Calif.
# 2 San Francisco, Calif.
# 3 Milton, Mass.
# 4 Keller, Texas
# 5 Northridge, Calif.
# 6 Cypress, Texas
# 7 Stamford, Conn.
# 8 Plantation, Florida.
# 9 Far Hills, N.J.
# 10 Medfield, Mass.
# 11 Duxbury, Mass.
# 12 Wellesley, Mass.
# 13 Darien, Conn.
# 14 Los Angeles, Calif.
# 15 Washington, D.C.
# 16 Houston, Texas
# 17 Manhattan Beach, Calif.
# 18 Andover, Mass.
# 19 Katy, Texas
# 20 Toronto, Ontario
# 21 Houston, Texas
# 22 Nashville, Tenn.
# 23 Fulshear, Texas
# 24 Douglasville, Ga.
# 25 Del Mar, Calif.
# 26 Huntington Beach, Calif.
# 27 Los Gatos, Calif.
# 28 Stamford, Conn.
# 29 Pacific Palisades, Calif.
# 30 Alpharetta, Ga.
# 31 Etobicoke, Ontario
# 32 Brooklyn, N.Y.
# 33 Brooklyn, N.Y.
# 34 Richmond, Va.
# 35 Ottawa, Ontario
# 36 Randolph, N.J.
# 37 Pacific Palisades, Calif.
# 38 Lexington, Mass.
# 39 Denver, Colo.
# 40 Folsom, Calif.
# 41 Tarzana, Calif.
# 42 O'Fallon, Mo.
# 43 Glencoe, Illinois
# 44 Brampton, Ontario
# 45 Columbus, Ohio
# 46 La Jolla, Calif.
# 47 Woodstock, Ga.
# 48 Redondo Beach, Calif.
# 49 Havertown, Pa.
# 50 Guaynabo, Puerto Rico
# 51 Winston-Salem, N.C.
# 52 Mission Viejo, Calif.
# 53 Johnson City, Tenn.
# 54 Valencia, Calif.
# 55 Briarcliff Manor, N.Y.
# 56 La Jolla, Calif.
# 57 Parkland, Florida.
# 58 Charlotte, N.C.
# 59 Waco, Texas
# 60 Atasehir, Istanbul, Turkey
# 61 Newton, Mass.
# 62 Bankeryd, Sweden
# 63 Lincoln University, Pa.
# 64 San Ramon, Calif.
# 65 Williamstown, Mass.
# 66 Hacienda Heights, Calif.
# 67 Brookfield, Wis.
# 68 Cypress, Texas
# 69 Union City, Calif.
# 70 Arlington Heights, Illinois
# 71 Singapore
# 72 Vienna, Austria
# 73 Lincoln, Nebraska
# 74 Chicago, Illinois
# 75 Cupertino, Calif.
# 76 Allentown, Pa.
# 77 Naperville, Illinois
# 78 Mechanicsburg, Pa.
# 79 Carmel, Ind.
# 80 Jackson, Tenn.
# 81 Arvada, Colo.
# 82 Cairo, Egypt
# 83 Belmont, Mass.
# 84 Winchester, U.K.
# 85 Var, France
# 86 Oakville, Ontario
# 87 Toronto, Ontario
# 88 Newton Square, Pa.
# 89 Edison, N.J.
# 90 Norwalk, Conn.
# 91 Bethesda, Md.
# 92 South Orange, New Jersey
# 93 Cairo, Egypt
# 94 Calgary, Alberta
# 95 Tadley, United Kingdom
# 96 London, England
# 97 Greenwich, Conn.
# 98 Salisbury, United Kingdom
# 99 Westport, Conn.

# %%
import csv

with open('Hometowns.csv', 'w', newline='') as myfile:
     wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
     wr.writerow(locations)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-2cbcb695ddcf> in <module>
# ----> 1 df['Clean Hometown'] = locations
#       2 import csv
#       3
#       4 with open('Hometowns.csv', 'w', newline='') as myfile:
#       5      wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
#
# c:\users\richa\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# c:\users\richa\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# c:\users\richa\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3732
#    3733             # turn me into an ndarray
# -> 3734             value = sanitize_index(value, self.index, copy=False)
#    3735             if not isinstance(value, (np.ndarray, Index)):
#    3736                 if isinstance(value, list) and len(value) > 0:
#
# c:\users\richa\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     610
#     611     if len(data) != len(index):
# --> 612         raise ValueError("Length of values does not match length of index")
#     613
#     614     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index
