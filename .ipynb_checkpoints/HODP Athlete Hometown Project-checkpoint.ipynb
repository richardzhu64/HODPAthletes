# %%
import numpy as np
import pandas

#import ssl
#import certifi
#import geopy.geocoders
#ctx = ssl.create_default_context(cafile=certifi.where())
#geopy.geocoders.options.default_ssl_context = ctx

import geopy as gp
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

geolocator = Nominatim(user_agent="hodp")

# %%
df = pandas.read_csv('HODP Athlete Project - All Athletes.csv', index_col = 0)
df = df[pandas.notnull(df['Hometown'])]
df = df.reset_index()
df.drop(columns = ['Unnamed: 8'])
df.head()
# Out:
#       Sport Gender            Name Yr.               Hometown  \
# 0  Baseball      M  Seamus Buckley  Fy      Dorchester, Mass.
# 1  Baseball      M     Ian Buckner  Fy       Oak Park, Calif.
# 2  Baseball      M   Will Jacobsen  Fy  San Francisco, Calif.
# 3  Baseball      M      Ben Rounds  Fy          Milton, Mass.
# 4  Baseball      M    Pryor Thomas  Fy          Keller, Texas
#
#                 High School  \
# 0        Beaver Country Day
# 1    Grace Brethren Academy
# 2        The Branson School
# 3             Roxbury Latin
# 4  Liberty Christian School
#
#   Median Household Income from datausa.io, or ZIP code from https://www.incomebyzipcode.com  \
# 0                                             71,723
# 1                                            129,721
# 2                                            110,816
# 3                                            126,000
# 4                                             126013
#
#   Private School Unnamed: 8
# 0              1    103,092
# 1              1        NaN
# 2              1        NaN
# 3              1        NaN
# 4              1        NaN

# %%
print(df.iloc[0].Hometown)
# Out:
# Dorchester, Mass.

# %%
def do_geocode(address):
    try:
        return geolocator.geocode(address)
    except GeocoderTimedOut:
        return do_geocode(address)

# %%
print(do_geocode("New York, New York"))
# Out:
# New York, United States of America

# %%
# Cleaner function
def cleaner(old, new):
    lst = [] 
    for i, row in df.iterrows():
        if old in row["Hometown"]:
            lst.append(i)

    print(lst)
    for i in lst:
        df.iloc[i]["Hometown"] = df.iloc[i]["Hometown"].replace(old, new)
        
cleaner("Ill.", "Illinois")
cleaner("Neb.", "Nebraska")
cleaner("Wisc.", "Wisconsin")
cleaner("Fla", "Florida")
cleaner("Coquitlan", "Coquitlam")
cleaner("Pozos de Santa", "Pozos")
cleaner("Cutchouge", "Cutchogue")
cleaner("Edgarton", "Edgartown")
# Out:
# [43, 70, 74, 77, 167, 204, 216, 220, 279, 360, 444, 452, 455, 456, 458, 497, 515, 541, 548, 620, 632, 639, 673, 675, 682, 699, 702, 759, 769, 779, 822, 863, 909, 992, 993, 1003, 1030]
# [73]
# [121, 568, 714]
# [8, 57, 107, 157, 163, 206, 244, 245, 254, 256, 284, 317, 334, 339, 340, 424, 436, 466, 471, 476, 494, 519, 553, 580, 595, 600, 631, 648, 667, 670, 830, 847, 927, 946, 947, 948, 1049]
# [474, 598]
# [662]
# [732]
# [967]

# %%
print(df.iloc[732].Hometown)
# Out:
# Cutchogue, N.Y.

# %%
df = df.iloc[0:len(df.Hometown)]
df
# Out:
#          Sport Gender                Name         Yr.  \
# 0     Baseball      M      Seamus Buckley          Fy
# 1     Baseball      M         Ian Buckner          Fy
# 2     Baseball      M       Will Jacobsen          Fy
# 3     Baseball      M          Ben Rounds          Fy
# 4     Baseball      M        Pryor Thomas          Fy
# ...        ...    ...                 ...         ...
# 1047    Tennis      F  Mihaela Marculescu  First-Year
# 1048    Tennis      F     Lexi Milunovich      Senior
# 1049    Tennis      F         Demi Snyder  First-Year
# 1050    Tennis      F    Chelsea Williams   Sophomore
# 1051    Tennis      F           Lauryn Wu  First-Year
#
#                       Hometown  \
# 0            Dorchester, Mass.
# 1             Oak Park, Calif.
# 2        San Francisco, Calif.
# 3                Milton, Mass.
# 4                Keller, Texas
# ...                        ...
# 1047        Bucharest, Romania
# 1048         New Canaan, Conn.
# 1049  Ft. Lauderdale, Florida.
# 1050            Brooklyn, N.Y.
# 1051               McLean, Va.
#
#                                             High School  \
# 0                                    Beaver Country Day
# 1                                Grace Brethren Academy
# 2                                    The Branson School
# 3                                         Roxbury Latin
# 4                              Liberty Christian School
# ...                                                 ...
# 1047                                        Tudor Vianu
# 1048                                  Greenwich Academy
# 1049                                  Pine Crest School
# 1050                                 Brooklyn Technical
# 1051  Thomas Jefferson High School for Science and T...
#
#      Median Household Income from datausa.io, or ZIP code from https://www.incomebyzipcode.com  \
# 0                                                71,723
# 1                                               129,721
# 2                                               110,816
# 3                                               126,000
# 4                                                126013
# ...                                                 ...
# 1047                                                NaN
# 1048                                            147,128
# 1049                                             52,315
# 1050                                             85,846
# 1051                                                NaN
#
#      Private School Unnamed: 8
# 0                 1    103,092
# 1                 1        NaN
# 2                 1        NaN
# 3                 1        NaN
# 4                 1        NaN
# ...             ...        ...
# 1047            NaN        NaN
# 1048            NaN        NaN
# 1049            NaN        NaN
# 1050            NaN        NaN
# 1051            NaN        NaN
#
# [1052 rows x 9 columns]

# %%
def do_geocode(address):
    try:
        return geolocator.geocode(address)
    except GeocoderTimedOut:
        return do_geocode(address)

# %%
my_df = df
print(my_df)
# Out:
#               Sport Gender                    Name         Yr.  \
# 0          Baseball      M          Seamus Buckley          Fy
# 1          Baseball      M             Ian Buckner          Fy
# 2          Baseball      M           Will Jacobsen          Fy
# 3          Baseball      M              Ben Rounds          Fy
# 4          Baseball      M            Pryor Thomas          Fy
# 5          Baseball      M        Spencer Williams          Fy
# 6          Baseball      M          Tim Williamson          Fy
# 7          Baseball      M              Adam Stone         Fy.
# 8          Baseball      M           Buddy Hayward         Jr.
# 9          Baseball      M             Jack Mahala         Jr.
# 10         Baseball      M           Chris McGrory         Jr.
# 11         Baseball      M            Buddy Mrowka         Jr.
# 12         Baseball      M             Tommy Seidl         Jr.
# 13         Baseball      M          Enzo Stefanoni         Jr.
# 14         Baseball      M             Matt Thomas         Jr.
# 15         Baseball      M              Jaren Zinn         Jr.
# 16         Baseball      M          Hunter Baldwin         So.
# 17         Baseball      M            Chase Bookin         So.
# 18         Baseball      M             Logan Bravo         So.
# 19         Baseball      M           Zachary Brown         So.
# 20         Baseball      M         Matthew Jenkins         So.
# 21         Baseball      M       James Kirkpatrick         So.
# 22         Baseball      M        Joseph O'Connell         So.
# 23         Baseball      M        Harrison Stovern         So.
# 24         Baseball      M              JT Bernard         Sr.
# 25         Baseball      M           Quinn Hoffman         Sr.
# 26         Baseball      M             Chad Minato         Sr.
# 27         Baseball      M             Kieran Shaw         Sr.
# 28         Baseball      M             Grant Stone         Sr.
# 29         Baseball      M          Jake Suddleson         Sr.
# ...             ...    ...                     ...         ...
# 1022  Cross Country      F  Valentina Doerre Torre   Sophomore
# 1023  Cross Country      F          Eloise Freitag  First-Year
# 1024  Cross Country      F          Abbe Goldstein      Junior
# 1025  Cross Country      F         Tatiana Jimenez      Junior
# 1026  Cross Country      F               Anna Juul      Junior
# 1027  Cross Country      F        Shaked Leibovitz  First-Year
# 1028  Cross Country      F           Tessa Medrano      Junior
# 1029  Cross Country      F           Gillian Meeks      Senior
# 1030  Cross Country      F         Judy Pendergast      Senior
# 1031  Cross Country      F              Maya Rayle   Sophomore
# 1032  Cross Country      F              Eliza Rego      Senior
# 1033  Cross Country      F                Iz Sagar  First-Year
# 1034  Cross Country      F            Brooke Starn      Senior
# 1035  Cross Country      F            Lisa Tertsch      Senior
# 1036  Cross Country      F           Jordan Weston   Sophomore
# 1037         Tennis      F           Annika Bassey   Sophomore
# 1038         Tennis      F            Rachel Eason   Sophomore
# 1039         Tennis      F           Jenna Friedel      Senior
# 1040         Tennis      F        Natasha Gonzalez      Senior
# 1041         Tennis      F              Neha Gupta      Junior
# 1042         Tennis      F               Sophia Ho  First-Year
# 1043         Tennis      F           Kayla Leschly  First-Year
# 1044         Tennis      F                 Anna Li      Junior
# 1045         Tennis      F              Rachel Lim   Sophomore
# 1046         Tennis      F                Irene Lu      Senior
# 1047         Tennis      F      Mihaela Marculescu  First-Year
# 1048         Tennis      F         Lexi Milunovich      Senior
# 1049         Tennis      F             Demi Snyder  First-Year
# 1050         Tennis      F        Chelsea Williams   Sophomore
# 1051         Tennis      F               Lauryn Wu  First-Year
#
#                           Hometown  \
# 0                Dorchester, Mass.
# 1                 Oak Park, Calif.
# 2            San Francisco, Calif.
# 3                    Milton, Mass.
# 4                    Keller, Texas
# 5               Northridge, Calif.
# 6                   Cypress, Texas
# 7                  Stamford, Conn.
# 8                 Plantation, Fla.
# 9                  Far Hills, N.J.
# 10                 Medfield, Mass.
# 11                  Duxbury, Mass.
# 12                Wellesley, Mass.
# 13                   Darien, Conn.
# 14             Los Angeles, Calif.
# 15                Washington, D.C.
# 16                  Houston, Texas
# 17         Manhattan Beach, Calif.
# 18                  Andover, Mass.
# 19                     Katy, Texas
# 20                Toronto, Ontario
# 21                  Houston, Texas
# 22                Nashville, Tenn.
# 23                 Fulshear, Texas
# 24               Douglasville, Ga.
# 25                 Del Mar, Calif.
# 26        Huntington Beach, Calif.
# 27               Los Gatos, Calif.
# 28                 Stamford, Conn.
# 29       Pacific Palisades, Calif.
# ...                            ...
# 1022                 Boston, Mass.
# 1023                New York, N.Y.
# 1024                   Ambler, Pa.
# 1025             Elk Grove, Calif.
# 1026             West Chester, Pa.
# 1027              Tel Aviv, Israel
# 1028                    Powell, OH
# 22                                               57,737
# 23                                              174,194
# 24                                               51,039
# 25                                              122,563
# 26                                               88,079
# 27                                              132,671
# 28                                               84,893
# 29                                              180,962
# ...                                                 ...
# 1022                                                NaN
# 1023                                             60,879
# 1024                                                NaN
# 1025                                                NaN
# 1026                                                NaN
# 1027                                                NaN
# 1028                                                NaN
# 1029                                            147,537
# 1030                                            114,014
# 1031                                             66,187
# 1032                                                NaN
# 1033                                                NaN
# 1034                                            152,798
# 1035                                                NaN
# 1036                                              65782
# 1037                                             65,224
# 1038                                             95,625
# 1039                                                NaN
# 1040                                             50,896
# 1041                                                NaN
# 1042                                                NaN
# 1043                                            196,651
# 1044                                                NaN
# 1045                                            157,963
# 1046                                                NaN
# 1047                                                NaN
# 1048                                            147,128
# 1049                                             52,315
# 1050                                             85,846
# 1051                                                NaN
#
#      Private School Unnamed: 8  \
# 0                 1    103,092
# 1                 1        NaN
# 2                 1        NaN
# 3                 1        NaN
# 4                 1        NaN
# 5                 1        NaN
# 6                 1        NaN
# 7                 1        NaN
# 8                 1        NaN
# 9                 1        NaN
# 10                0        NaN
# 11                1        NaN
# 12                1        NaN
# 13                1        NaN
# 14                1        NaN
# 15                1        NaN
# 16                0        NaN
# 17                1        NaN
# 18                1        NaN
# 19                0        NaN
# 20                1        NaN
# 21                0        NaN
# 22                1        NaN
# 23                0        NaN
# 24                1        NaN
# 25                1        NaN
# 26                0        NaN
# 27                1        NaN
# 28                1        NaN
# 29                1        NaN
# ...             ...        ...
# 1022            NaN        NaN
# 1023            NaN        NaN
# 1024            NaN        NaN
# 1025            NaN        NaN
# 1026            NaN        NaN
# 1027            NaN        NaN
# 1028            NaN        NaN
# 1029            NaN        NaN
# 1030            NaN        NaN
# 1031            NaN        NaN
# 1032            NaN        NaN
# 1033            NaN        NaN
# 1034            NaN        NaN
# 1035            NaN        NaN
# 1036            NaN        NaN
# 1037            NaN        NaN
# 1038            NaN        NaN
# 1039            NaN        NaN
# 1040            NaN        NaN
# 1041            NaN        NaN
# 1042            NaN        NaN
# 1043            NaN        NaN
# 1044            NaN        NaN
# 1045            NaN        NaN
# 1046            NaN        NaN
# 1047            NaN        NaN
# 1048            NaN        NaN
# 1049            NaN        NaN
# 1050            NaN        NaN
# 1051            NaN        NaN
#
#                                               CHometown
# 0     Dorchester, Boston, Suffolk County, Massachuse...
# 1     Oak Park, Ventura County, California, 91377, U...
# 2     San Francisco, San Francisco City and County, ...
# 3     Milton, Norfolk County, Massachusetts, United ...
# 4          Keller, Tarrant County, Texas, United States
# 5     Northridge, Los Angeles, Los Angeles County, C...
# 6     Cypress, Harris County, Texas, 77433, United S...
# 7     Stamford, Fairfield, Connecticut, United State...
# 8     Plantation, Monroe County, Florida, 33070, Uni...
# 9     Far Hills, Somerset County, New Jersey, United...
# 10    Medfield, Norfolk County, Massachusetts, 02052...
# 11    Duxbury, Plymouth County, Massachusetts, Unite...
# 12    Wellesley, Norfolk County, Massachusetts, Unit...
# 13    Darien, Fairfield, Connecticut, 06820, United ...
# 14    Los Angeles, Los Angeles County, California, U...
# 15    Washington, District of Columbia, United State...
# 16    Houston, Harris County, Texas, United States o...
# 17    Manhattan Beach, Los Angeles County, Californi...
# 18    Andover, Essex County, Massachusetts, United S...
# 19         Katy, Fort Bend County, Texas, United States
# 20    Toronto, Golden Horseshoe, Ontario, M6K 1X9, C...
# 21    Houston, Harris County, Texas, United States o...
# 22    Nashville-Davidson, Davidson County, Tennessee...
# 23    Fulshear, Fort Bend County, Texas, 77441, Unit...
# 24    Douglasville, Douglas County, Georgia, United ...
# 25    Del Mar, San Diego County, California, United ...
# 26    Huntington Beach, Orange County, California, U...
# 27    Los Gatos, Santa Clara County, California, Uni...
# 28    Stamford, Fairfield, Connecticut, United State...
# 29    Pacific Palisades, Los Angeles, Los Angeles Co...
# ...                                                 ...
# 1022                                                NaN
# 1023                                                NaN
# 1024                                                NaN
# 1025                                                NaN
# 1026                                                NaN
# 1027                                                NaN
# 1028                                                NaN
# 1029                                                NaN
# 1030                                                NaN
# 1031                                                NaN
# 1032                                                NaN
# 1033                                                NaN
# 1034                                                NaN
# 1035                                                NaN
# 1036                                                NaN
# 1037                                                NaN
# 1038                                                NaN
# 1039                                                NaN
# 1040                                                NaN
# 1041                                                NaN
# 1042                                                NaN
# 1043                                                NaN
# 1044                                                NaN
# 1045                                                NaN
# 1046                                                NaN
# 1047                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
#
# [1052 rows x 10 columns]

# %%
locations = []
my_df = df

for index, row in my_df.iterrows():
    location = do_geocode(row["Hometown"])
    print(index, location)
#    my_df.loc[index, 'CHometown'] = location.address
#    print(index)
#    print(location.address)
    if location:
        locations.append(location)
    else:
        locations.append("")

my_df['CHometown'] = locations
# Out:
# 0 Dorchester, Boston, Suffolk County, Massachusetts, 02124, United States
# 1 Oak Park, Ventura County, California, 91377, United States
# 2 San Francisco, San Francisco City and County, California, United States of America
# 3 Milton, Norfolk County, Massachusetts, United States of America
# 4 Keller, Tarrant County, Texas, United States
# 5 Northridge, Los Angeles, Los Angeles County, California, United States of America
# 6 Cypress, Harris County, Texas, 77433, United States
# 7 Stamford, Fairfield, Connecticut, United States of America
# 8 Plantation, Monroe County, Florida, 33070, United States
# 9 Far Hills, Somerset County, New Jersey, United States
# 10 Medfield, Norfolk County, Massachusetts, 02052, United States of America
# 11 Duxbury, Plymouth County, Massachusetts, United States of America
# 12 Wellesley, Norfolk County, Massachusetts, United States of America
# 13 Darien, Fairfield, Connecticut, 06820, United States
# 14 Los Angeles, Los Angeles County, California, United States of America
# 15 Washington, District of Columbia, United States of America
# 16 Houston, Harris County, Texas, United States of America
# 17 Manhattan Beach, Los Angeles County, California, 90266, United States
# 18 Andover, Essex County, Massachusetts, United States of America
# 19 Katy, Fort Bend County, Texas, United States
# 20 Toronto, Golden Horseshoe, Ontario, M6K 1X9, Canada
# 21 Houston, Harris County, Texas, United States of America
# 188 Oslo, 0026, Norge
# 189 Dunbarton, Merrimack County, New Hampshire, 03046, United States
# 190 St. Louis, City of Saint Louis, Missouri, United States of America
# 191 Brookline, Norfolk County, Massachusetts, United States of America
# 192 New Albany, Plain Township, Franklin County, Ohio, 43054, United States
# 193 Sudbury, Middlesex County, Massachusetts, 01776, United States
# 194 Greenwich, Fairfield, Connecticut, United States of America
# 195 Newton, Middlesex County, Massachusetts, United States of America
# 196 Belmont, Middlesex County, Massachusetts, United States
# 197 Berlin, 10117, Deutschland
# 198 North Charleston, Charleston County, South Carolina, United States
# 199 Devon, South West England, England, United Kingdom
# 200 Swindon, South West England, England, SN1 1JH, United Kingdom
# 201 Princeton Junction, Mercer County, New Jersey, 08537, United States
# 202 Manchester-by-the-Sea, Essex County, Massachusetts, 01944, United States of America
# 203 Suffield, Hartford County, Connecticut, 06078, United States
# 204 None
# 205 Waterloo, Waterloo Region, Southwestern Ontario, Ontario, Canada
# 206 Sarasota Heights, Sarasota County, Florida, 34239, United States
# 207 Roseville, Ramsey County, Minnesota, United States
# 208 Kalaheo, Kauaʻi County, Hawaii, 96765, United States of America (Kaua'i, Ni'ihau, Ka'ula)
# 209 Yarmouth, Cumberland County, Maine, United States
# 210 Frederick, Frederick County, Maryland, United States
# 211 Cleveland, Cuyahoga County, Ohio, United States
# 212 Greensboro, Guilford County, North Carolina, United States of America
# 213 Αθήνα, Δήμος Αθηναίων, Περιφερειακή Ενότητα Κεντρικού Τομέα Αθηνών, Περιφέρεια Αττικής, Αττική, 10431, Ελλάδα
# 214 Derby, East Midlands, England, DE1 2AA, United Kingdom
# 215 Plattsburgh, Clinton County, New York, United States of America
# 216 None
# 217 Wilmington, New Castle County, Delaware, United States
# 218 San Francisco, San Francisco City and County, California, United States of America
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
# ...
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-47-dbf3dbff9dc3> in do_geocode(address)
#       1 def do_geocode(address):
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#       5         return do_geocode(address)
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     385
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#     389
#
# /anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     353
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#     357             message = (
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#    1382             "Connect to a host on a given (SSL) port."
#    1383
# -> 1384             super().connect()
#    1385
#    1386             if self._tunnel_host:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     926         """Connect to the host and port specified in __init__."""
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     930
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:

# %%
for i in range(len(my_loc)):
    #print(type(my_loc[i]))
    if type(my_loc[i]) == geopy.location.Location:
        my_loc[i] = my_loc[i].address
        
my_loc
# Out:
# ['Dorchester, Boston, Suffolk County, Massachusetts, 02124, United States',
#  'Oak Park, Ventura County, California, 91377, United States',
#  'San Francisco, San Francisco City and County, California, United States of America',
#  'Milton, Norfolk County, Massachusetts, United States of America',
#  'Keller, Tarrant County, Texas, United States',
#  'Northridge, Los Angeles, Los Angeles County, California, United States of America',
#  'Cypress, Harris County, Texas, 77433, United States',
#  'Stamford, Fairfield, Connecticut, United States of America',
#  'Plantation, Monroe County, Florida, 33070, United States',
#  'Far Hills, Somerset County, New Jersey, United States',
#  'Medfield, Norfolk County, Massachusetts, 02052, United States of America',
#  'Duxbury, Plymouth County, Massachusetts, United States of America',
#  'Wellesley, Norfolk County, Massachusetts, United States of America',
#  'Darien, Fairfield, Connecticut, 06820, United States',
#  'Los Angeles, Los Angeles County, California, United States of America',
#  'Washington, District of Columbia, United States of America',
#  'Houston, Harris County, Texas, United States of America',
#  'Manhattan Beach, Los Angeles County, California, 90266, United States',
#  'Andover, Essex County, Massachusetts, United States of America',
#  'Katy, Fort Bend County, Texas, United States',
#  'Toronto, Golden Horseshoe, Ontario, M6K 1X9, Canada',
#  'Houston, Harris County, Texas, United States of America',
#  'Nashville-Davidson, Davidson County, Tennessee, United States of America',
#  'Fulshear, Fort Bend County, Texas, 77441, United States',
#  'Douglasville, Douglas County, Georgia, United States of America',
#  'Del Mar, San Diego County, California, United States',
#  'Huntington Beach, Orange County, California, United States of America',
#  'Los Gatos, Santa Clara County, California, United States',
#  'Stamford, Fairfield, Connecticut, United States of America',
#  'Pacific Palisades, Los Angeles, Los Angeles County, California, 90272-3719, United States',
#  'Alpharetta, Fulton County, Georgia, United States',
#  'Etobicoke, Toronto, Golden Horseshoe, Ontario, Canada',
#  'Brooklyn, Kings County, New York, United States of America',
#  'Brooklyn, Kings County, New York, United States of America',
#  'Richmond, Richmond City, Virginia, 23298, United States',
#  'Ottawa, Eastern Ontario, Ontario, K1P 1J1, Canada',
#  'Randolph, Norfolk County, Massachusetts, United States of America',
#  'Pacific Palisades, Los Angeles, Los Angeles County, California, 90272-3719, United States',
#  'Lexington, Middlesex County, Massachusetts, United States',
#  'Denver, Denver County, Colorado, United States of America',
#  'Folsom, Sacramento County, California, United States',
#  'Tarzana, Los Angeles, Los Angeles County, California, 91356, United States',
#  'O’Fallon, Saint Charles County, Missouri, United States of America',
#  '',
#  'Brampton, Peel Region, Golden Horseshoe, Ontario, Canada',
#  'Columbus, Franklin County, Ohio, United States of America',
#  'La Jolla, San Diego County, California, 92037, United States',
#  'Woodstock, Cherokee County, Georgia, 30075:30188, United States',
#  'Redondo Beach, Los Angeles County, California, United States',
#  'Havertown, Delaware County, Pennsylvania, 19083, United States',
#  'Guaynabo, Puerto Rico, 00969, United States of America',
#  'Winston-Salem, Forsyth County, North Carolina, United States of America',
#  'Mission Viejo, Orange County, California, United States of America',
#  'Johnson City, Washington County, Tennessee, United States of America',
#  'Valencia, San Bernardino County, California, 92404, United States',
#  'Briarcliff Manor, Town of Ossining, Westchester County, New York, 10510, United States',
#  'La Jolla, San Diego County, California, 92037, United States',
#  'Parkland, Broward County, Florida, 33067, United States',
#  'Charlotte, Mecklenburg County, North Carolina, United States of America',
#  'Waco, McLennan County, Texas, United States of America',
#  'Ataşehir, İstanbul, Marmara Bölgesi, Türkiye',
#  'Newton, Middlesex County, Massachusetts, United States of America',
#  'Bankeryd, Jönköpings kommun, Jönköpings län, Götaland, 564 35, Sverige',
#  'Lincoln University, 1570, Baltimore Pike, Upper Oxford Township, Chester County, Pennsylvania, 19352, United States',
#  'San Ramon, Contra Costa County, California, United States',
#  'Williamstown, Berkshire County, Massachusetts, 01267, United States of America',
#  'Hacienda Heights, Hillgrove, Los Angeles County, California, 91745, United States',
#  'Brookfield, Waukesha County, Wisconsin, United States of America',
#  'Cypress, Harris County, Texas, 77433, United States',
#  'Union City, Alameda County, California, 94587, United States of America',
#  'Arlington Heights, Sangamon County, Illinois, 62769, United States',
#  'Singapore, Central, Singapore',
#  'Wien, 1010, Österreich',
#  '',
#  'Chicago Lawn, Chicago, Cook County, Illinois, 60629, United States of America',
#  'Cupertino, Santa Clara County, California, United States',
#  'Allentown, Lehigh County, Pennsylvania, United States of America',
#  '',
#  'Mechanicsburg, Cumberland County, Pennsylvania, United States of America',
#  'Carmel, Hamilton County, Indiana, United States of America',
#  'Jackson, Madison County, Tennessee, United States',
#  'Arvada, Jefferson County, Colorado, United States',
#  'القاهرة, محافظة القاهرة, مصر',
#  'Belmont, Middlesex County, Massachusetts, United States',
#  'Winchester, Hampshire, South East, England, United Kingdom',
#  "Var, Provence-Alpes-Côte d'Azur, France métropolitaine, France",
#  'Oakville, Halton Region, Golden Horseshoe, Ontario, Canada',
#  'Toronto, Golden Horseshoe, Ontario, M6K 1X9, Canada',
#  'Newton Square, Moon Township, Allegheny County, Pennsylvania, 15108, United States',
#  'Edison, Middlesex County, New Jersey, United States of America',
#  'Norwalk, Fairfield, Connecticut, United States',
#  'Bethesda, Montgomery County, Maryland, 22814, United States',
#  'South Orange, Essex County, New Jersey, United States',
#  'القاهرة, محافظة القاهرة, مصر',
#  'Calgary, Alberta, Canada',
#  'Tadley, Basingstoke and Deane, Hampshire, South East, England, United Kingdom',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'Greenwich, Fairfield, Connecticut, United States of America',
#  'Salisbury, Wiltshire, South West England, England, SP1 1EU, United Kingdom',
#  'Westport, Fairfield, Connecticut, 06880, United States of America',
#  'Sydney, New South Wales, Australia',
#  'Hamilton, Hamilton City, Waikato, 3247, New Zealand',
#  'Montclair, Essex County, New Jersey, United States of America',
#  'Los Angeles, Los Angeles County, California, United States of America',
#  'Banbury, Oxfordshire, South East, England, OX16 0AA, United Kingdom',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'Amsterdam, Noord-Holland, Nederland',
#  'Sarasota Heights, Sarasota County, Florida, 34239, United States',
#  'Hattingen, Ennepe-Ruhr-Kreis, Regierungsbezirk Arnsberg, Nordrhein-Westfalen, Deutschland',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'Weston, Middlesex County, Massachusetts, 02493, United States',
#  'St. Louis, City of Saint Louis, Missouri, United States of America',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'Arlington, Arlington County, Virginia, United States',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'South Setauket, Suffolk County, New York, 11794, United States',
#  'Summit, Union County, New Jersey, United States',
#  'Kurraba Point, Lower North Shore, Sydney, North Sydney Council, New South Wales, 2089, Australia',
#  'Slough, South East, England, SL1 1XN, United Kingdom',
#  'Seattle, King County, Washington, United States of America',
#  'Barrington, Cook County, Illinois, United States',
#  '',
#  'City of Melbourne, Victoria, Australia',
#  'South Yarra, City of Stonnington, Victoria, 3165, Australia',
#  'Hamilton, Hamilton City, Waikato, 3247, New Zealand',
#  'Seattle, King County, Washington, United States of America',
#  'Clear Creek, Cleburne County, Alabama, 36264, United States',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'Darien, Fairfield, Connecticut, 06820, United States',
#  'Moraga, Contra Costa County, California, United States of America',
#  'San Francisco, San Francisco City and County, California, United States of America',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'Portland, Multnomah County, Oregon, United States of America',
#  'Belmont, Middlesex County, Massachusetts, United States',
#  'Berkeley, Alameda County, California, United States of America',
#  'Salisbury, Wiltshire, South West England, England, SP1 1EU, United Kingdom',
#  'Stillwater, Payne County, Oklahoma, United States of America',
#  'Needham, Norfolk County, Massachusetts, United States of America',
#  'Ramstein, Ramstein-Miesenbach, Landkreis Kaiserslautern, Rheinland-Pfalz, 66877, Deutschland',
#  'Alexandria, Virginia, United States',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'Sydney, New South Wales, Australia',
#  'Cape Town, City of Cape Town, Western Cape, 8001, South Africa',
#  'Hamburg, 20095, Deutschland',
#  'Brookline, Norfolk County, Massachusetts, United States of America',
#  'Port Washington, Nassau County, New York, United States',
#  'Bethesda, Montgomery County, Maryland, 22814, United States',
#  'Newtown, Fairfield, Connecticut, United States',
#  'Denver, Denver County, Colorado, United States of America',
#  'New York, United States of America',
#  'Potomac, Montgomery County, Maryland, 20854, United States',
#  'Brookline, Norfolk County, Massachusetts, United States of America',
#  'Fenwick, Niagara Region, Golden Horseshoe, Ontario, L0S 1C0, Canada',
#  'Cambridge, Middlesex County, Massachusetts, United States of America',
#  'Dallas, Dallas County, Texas, United States of America',
#  'Arlington, Middlesex County, Massachusetts, United States',
#  'Austin, Travis County, Texas, United States of America',
#  'South Miami Heights, Miami-Dade County, Florida, 33157-7610, United States',
#  'Belmont, Middlesex County, Massachusetts, United States',
#  'Greenwich, Fairfield, Connecticut, United States of America',
#  'Houston, Harris County, Texas, United States of America',
#  'Greenwich, Fairfield, Connecticut, United States of America',
#  'Menlo Park, San Mateo County, California, United States of America',
#  'Hobe Sound, Martin County, Florida, 33455, United States',
#  'Manhasset, Nassau County, New York, United States',
#  'İstanbul, Fatih, İstanbul, Marmara Bölgesi, 34126, Türkiye',
#  'Columbus, Franklin County, Ohio, United States of America',
#  '',
#  'New York, United States of America',
#  'Pacific Palisades, Los Angeles, Los Angeles County, California, 90272-3719, United States',
#  'Newport Beach, Orange County, California, United States of America',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'Anchorage, Alaska, United States',
#  'Stamford, Fairfield, Connecticut, United States of America',
#  'Reeders, Monroe County, Pennsylvania, 18352, United States',
#  'Arlington, Middlesex County, Massachusetts, United States',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'Minneapolis, Hennepin County, Minnesota, United States',
#  'London, Greater London, England, SW1A 2DX, United Kingdom',
#  'Danville, Contra Costa County, California, 94526, United States',
#  'Locust Valley, Nassau County, New York, 11560-1733, United States',
#  'Cranston, Providence County, Rhode Island, United States of America',
#  'Los Angeles, Los Angeles County, California, United States of America',
#  'Palo Alto, Santa Clara County, California, United States of America',
#  'Lexington, Middlesex County, Massachusetts, United States',
#  'Lexington, Middlesex County, Massachusetts, United States',
#  'Buffalo, Erie County, New York, United States',
#  'Beverly Hills, Los Angeles County, California, United States',
#  'Oslo, 0026, Norge',
#  'Dunbarton, Merrimack County, New Hampshire, 03046, United States',
#  'St. Louis, City of Saint Louis, Missouri, United States of America',
#  'Brookline, Norfolk County, Massachusetts, United States of America',
#  'New Albany, Plain Township, Franklin County, Ohio, 43054, United States',
#  'Sudbury, Middlesex County, Massachusetts, 01776, United States',
#  'Greenwich, Fairfield, Connecticut, United States of America',
#  'Newton, Middlesex County, Massachusetts, United States of America',
#  'Belmont, Middlesex County, Massachusetts, United States',
#  'Berlin, 10117, Deutschland',
#  'North Charleston, Charleston County, South Carolina, United States',
#  'Devon, South West England, England, United Kingdom',
#  'Swindon, South West England, England, SN1 1JH, United Kingdom',
#  'Princeton Junction, Mercer County, New Jersey, 08537, United States',
#  'Manchester-by-the-Sea, Essex County, Massachusetts, 01944, United States of America',
#  'Suffield, Hartford County, Connecticut, 06078, United States',
#  '',
#  'Waterloo, Waterloo Region, Southwestern Ontario, Ontario, Canada',
#  'Sarasota Heights, Sarasota County, Florida, 34239, United States',
#  'Roseville, Ramsey County, Minnesota, United States',
#  "Kalaheo, Kauaʻi County, Hawaii, 96765, United States of America (Kaua'i, Ni'ihau, Ka'ula)",
#  'Yarmouth, Cumberland County, Maine, United States',
#  'Frederick, Frederick County, Maryland, United States',
#  'Cleveland, Cuyahoga County, Ohio, United States',
#  'Greensboro, Guilford County, North Carolina, United States of America',
#  'Αθήνα, Δήμος Αθηναίων, Περιφερειακή Ενότητα Κεντρικού Τομέα Αθηνών, Περιφέρεια Αττικής, Αττική, 10431, Ελλάδα',
#  'Derby, East Midlands, England, DE1 2AA, United Kingdom',
#  'Plattsburgh, Clinton County, New York, United States of America',
#  '',
#  'Wilmington, New Castle County, Delaware, United States',
#  'San Francisco, San Francisco City and County, California, United States of America']

# %%
my_df = my_df[:len(my_loc)]
export_csv = my_df.to_csv(r'some_athlete_chometown.csv')
#my_df['CHometown'] = my_loc

# %%
import csv

with open('some_athlete_chometown.csv', 'w', newline='') as myfile:
     wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
     wr.writerow(locations)

# %%
town_locations = [i.split(',')[0] for i in locations]
print(town_locations)
# Out:
# ['Dorchester', 'Oak Park', 'San Francisco', 'Milton', 'Keller', 'Northridge', 'Cypress', 'Stamford', 'Plantation', 'Far Hills', 'Medfield', 'Duxbury', 'Wellesley', 'Darien', 'Los Angeles', 'Washington', 'Houston', 'Manhattan Beach', 'Andover', 'Katy', 'Toronto', 'Houston', 'Nashville-Davidson', 'Fulshear', 'Douglasville', 'Del Mar', 'Huntington Beach', 'Los Gatos', 'Stamford', 'Pacific Palisades', 'Alpharetta', 'Etobicoke', 'Brooklyn', 'Brooklyn', 'Richmond', 'Ottawa', 'Randolph', 'Pacific Palisades', 'Lexington', 'Denver', 'Folsom', 'Tarzana', 'O’Fallon', '', 'Brampton', 'Columbus', 'La Jolla', 'Woodstock', 'Redondo Beach', 'Havertown', 'Guaynabo', 'Winston-Salem', 'Mission Viejo', 'Johnson City', 'Valencia', 'Briarcliff Manor', 'La Jolla', 'Parkland', 'Charlotte', 'Waco', 'Ataşehir', 'Newton', 'Bankeryd', 'Lincoln University', 'San Ramon', 'Williamstown', 'Hacienda Heights', 'Brookfield', 'Cypress', 'Union City', 'Arlington Heights', 'Singapore', 'Wien', '', 'Chicago Lawn', 'Cupertino', 'Allentown', '', 'Mechanicsburg', 'Carmel', 'Jackson', 'Arvada', 'القاهرة', 'Belmont', 'Winchester', 'Var', 'Oakville', 'Toronto', 'Newton Square', 'Edison', 'Norwalk', 'Bethesda', 'South Orange', 'القاهرة', 'Calgary', 'Tadley', 'London', 'Greenwich', 'Salisbury', 'Westport', 'Sydney', 'Hamilton', 'Montclair', 'Los Angeles', 'Banbury', 'London', 'Amsterdam', 'Sarasota Heights', 'Hattingen', 'London', 'Weston', 'St. Louis', 'London', 'Arlington', 'London', 'South Setauket', 'Summit', 'Kurraba Point', 'Slough', 'Seattle', 'Barrington', '', 'City of Melbourne', 'South Yarra', 'Hamilton', 'Seattle', 'Clear Creek', 'London', 'Darien', 'Moraga', 'San Francisco', 'London', 'Portland', 'Belmont', 'Berkeley', 'Salisbury', 'Stillwater', 'Needham', 'Ramstein', 'Alexandria', 'London', 'Sydney', 'Cape Town', 'Hamburg', 'Brookline', 'Port Washington', 'Bethesda', 'Newtown', 'Denver', 'New York', 'Potomac', 'Brookline', 'Fenwick', 'Cambridge', 'Dallas', 'Arlington', 'Austin', 'South Miami Heights', 'Belmont', 'Greenwich', 'Houston', 'Greenwich', 'Menlo Park', 'Hobe Sound', 'Manhasset', 'İstanbul', 'Columbus', '', 'New York', 'Pacific Palisades', 'Newport Beach', 'London', 'Anchorage', 'Stamford', 'Reeders', 'Arlington', 'London', 'Minneapolis', 'London', 'Danville', 'Locust Valley', 'Cranston', 'Los Angeles', 'Palo Alto', 'Lexington', 'Lexington', 'Buffalo', 'Beverly Hills', 'Oslo', 'Dunbarton', 'St. Louis', 'Brookline', 'New Albany', 'Sudbury', 'Greenwich', 'Newton', 'Belmont', 'Berlin', 'North Charleston', 'Devon', 'Swindon', 'Princeton Junction', 'Manchester-by-the-Sea', 'Suffield', '', 'Waterloo', 'Sarasota Heights', 'Roseville', 'Kalaheo', 'Yarmouth', 'Frederick', 'Cleveland', 'Greensboro', 'Αθήνα', 'Derby', 'Plattsburgh', '', 'Wilmington', 'San Francisco']

# %%
locdict = {}
for loc in town_locations:
    if (loc in locdict):
        locdict[loc] += 1
    else:
        locdict[loc] = 1

loc_df = pandas.DataFrame.from_dict(locdict, orient='index')

# %%
export_csv = loc_df.to_csv(r'some_athlete_location_count.csv')
